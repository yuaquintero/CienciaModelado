# %% [markdown]
# <a href="https://colab.research.google.com/github/yuaquintero/CienciaModelado/blob/main/bicycle_model_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#para conectar el drive e importar el modelo

from google.colab import drivedrive.mount('/content/drive')

# %%
#Navego hasta la ruta donde está el modelo en las caprtas de mi drive
cd /content/drive/MyDrive/Colab Notebooks/CienciaModelado/BuckiNet
# Out:
# /content/drive/MyDrive/Colab Notebooks/CienciaModelado/BuckiNet

# %% [markdown]
# # Problema fisico:
# Definir la trayectoria de la bicicleta
#
#
# \begin{equation}
# \dot{X}=Vcos(ψ+β)
# \end{equation}
#
# \begin{equation}
# \dot{Y}=Vsin(ψ+β)
# \end{equation}
#
# \begin{equation}
# \dot{ψ}= \frac{V}{l_r}sin(β)
# \end{equation}
#
# Donde β es el ángulo de deslizamiento del CG, calculado a partir de la geometría del vehículo y el ángulo de dirección δ:
#
# \begin{equation} β = \arctan(\frac {l_r}{l_f+l_r} \tan(δ)) \end{equation}

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# Importamos las clases locales en src/model.py
# NOTA: correr este notebook desde la carpeta 'notebooks'
# y que exista el archivo '../src/model.py'
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.model import FullBuckiNet, buckinet_loss, BuckiNetLayer

# Configuración para reproducibilidad
torch.manual_seed(42)
np.random.seed(42)

# %%
print("Interpretación de exponentes (Ley de Buckingham)")

exponentes = Phi_final.detach().numpy()
nombres_vars = ['l_f', 'l_r', 'δ', 'V',  't']

print(f"\nMatriz de exponentes aprendidos Φ (forma: {exponentes.shape}):")
# La matriz 'exponentes' tiene forma (num_inputs, num_pi_groups).
# Para imprimir como 'Cada fila es un grupo adimensional Πᵢ', iteramos sobre las columnas.
print("   Cada columna de la matriz es un grupo adimensional Πᵢ")
print("   Cada fila de la matriz es un exponente de una variable de entrada\n")

# Iterar sobre los grupos Pi (columnas de 'exponentes')
for pi_group_idx in range(exponentes.shape[1]): # exponentes.shape[1] es el número de grupos Pi (4)
    print(f"   Π_{pi_group_idx+1}: ", end="")
    # Iterar sobre las variables de entrada (filas de 'exponentes')
    for var_idx, nombre in enumerate(nombres_vars): # len(nombres_vars) es el número de variables (6)
        # Acceder a exponente[índice_variable, índice_grupo_pi]
        print(f"{nombre}^{exponentes[var_idx, pi_group_idx]:+.3f} ", end="")
    print()
# Out:
# Interpretación de exponentes (Ley de Buckingham)
#
# Matriz de exponentes aprendidos Φ (forma: (5, 3)):
#    Cada columna de la matriz es un grupo adimensional Πᵢ
#    Cada fila de la matriz es un exponente de una variable de entrada
#
#    Π_1: l_f^-0.212 l_r^-0.344 δ^+0.587 V^+0.579 t^+0.765
#    Π_2: l_f^+0.311 l_r^-0.113 δ^-1.212 V^+0.051 t^-0.314
#    Π_3: l_f^+0.290 l_r^-0.168 δ^-0.844 V^-0.336 t^-0.313

# %% [markdown]
# ## Paso 1. Generación de Datos Sintéticos

# %%
import numpy as np
from scipy.integrate import solve_ivp
import torch

def bicicleta_ode(t, y, V, delta, lf, lr):
    # y = [X, Y, psi]
    psi = y[2]
    L = lf + lr
    beta = np.arctan(np.tan(delta) * lr / L)

    # Ecuaciones acopladas de la trayectoria
    dx_dt = V * np.cos(psi + beta)
    dy_dt = V * np.sin(psi + beta)
    dpsi_dt = (V / L) * np.tan(delta) * np.cos(beta)

    return [dx_dt, dy_dt, dpsi_dt]

def generar_datos_sinteticos_ode(n_samples=10000):
    inputs = []
    targets = []

    for _ in range(n_samples):
        # Parámetros aleatorios (siempre positivos para BuckiNet)
        lf = np.random.uniform(1.0, 1.2)
        lr = np.random.uniform(1.2, 1.8)
        V = np.random.uniform(3.0, 15.0)
        delta = np.random.uniform(0.05, 0.4)
        t_final = np.random.uniform(0.1, 4.0)

        # Resolver el sistema acoplado
        sol = solve_ivp(
            bicicleta_ode,
            [0, t_final],
            [0.0, 0.0, 0.0], # Condiciones iniciales: X=0, Y=0, psi=0
            args=(V, delta, lf, lr),
            t_eval=[t_final]
        )

        if sol.status == 0:
            inputs.append([lf, lr, delta, V, t_final])
            # Guardamos X, Y, psi al tiempo t_final
            targets.append([sol.y[0,0], sol.y[1,0], sol.y[2,0]])

    return torch.tensor(inputs, dtype=torch.float32), torch.tensor(targets, dtype=torch.float32)

# Crear dataset
X_train, Y_train = generar_datos_sinteticos_ode(10000)

# %%
print(f"\nTensores creados:")
print(f"   X_train (entradas): shape {X_train.shape}")
print(f"   Y_train (salidas):  shape {Y_train.shape}")
# Out:
# Tensores creados:
#    X_train (entradas): shape torch.Size([10000, 5])
#    Y_train (salidas):  shape torch.Size([10000, 3])

# %% [markdown]
# ## Paso 2. Configuración de la Red y la Física
#
# Matriz Dimencional, solo tenemos Longitud (L) y Tiempo (T).
#
#
# | Variable | Unidades | Longitud (L) | Tiempo (T) |
# | :--- | :--- | :---: | :---: |
# | l_f| $m$ | 1 | 0 |
# |l_r | $m$ | 1 | 0 |
# | δ| $º$ | 0 | 0 |
# | V | $m/s$ | 1 | -1 |
# | t | $s$ | 0 | 1 |

# %%
# Dimensiones: Longitud [L], Tiempo [T]
# Variables: [l_f, l_r, δ, V, t]


print("\nMatriz dimensional D_p (2 filas x 5 columnas):")
print("   Filas: [Longitud (L), Tiempo (T)]")
print("   Columnas: [l_f, l_r, δ, V,  t]")

print("Matriz Dimensional D_p (Bicicleta):")

D_p_numpy = np.array([
    #  l_f  l_r   δ    V    t
    [   1,   1,   0,   1,   0 ],   # Longitud (L)
    [   0,   0,   0,  -1,   1 ]    # Tiempo (T)
], dtype=np.float32)

D_p = torch.tensor(D_p_numpy, dtype=torch.float32)

print("\n" + str(D_p.numpy()))
# Instanciamos el modelo
# Usamos un poco más de neuronas ocultas porque ahora hay 3 salidas acopladas
# Arquitectura:
# - 6 entradas: [l_f, l_r, δ, V, t] -> n
# - 2 dimensiones fundamentales -> k
# - 4 grupos Pi (teorema Pi: n-k = 6-2 = 4)
# - 3 salidas: [X, Y, ψ]
# - 128 neuronas en capa oculta

modelo = FullBuckiNet(
    num_inputs=5,        # l_f, l_r, δ, V, t
    num_pi_groups=3,     # 3 grupos adimensionales
    num_outputs=3,       # X, Y, ψ
    hidden_neurons=128
)

# Optimizador Adam con learning rate moderado
optimizador = optim.Adam(modelo.parameters(), lr=0.001)
# Out:
# Matriz dimensional D_p (2 filas x 5 columnas):
#    Filas: [Longitud (L), Tiempo (T)]
#    Columnas: [l_f, l_r, δ, V,  t]
# Matriz Dimensional D_p (Bicicleta):
#
# [[ 1.  1.  0.  1.  0.]
#  [ 0.  0.  0. -1.  1.]]

# %% [markdown]
# ## Paso 3. Bucle de Entrenamiento
#
# Usamos Buckinet

# %%
import torch.nn as nn

# 1. Parámetros de entrenamiento
num_epochs = 5000
lambda_fisica = 10.0  # Empezamos con una penalización fuerte
historial_total = []
historial_mse = []
historial_fisica = []
#l1_reg=1e-3, l2_reg=1e-4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
modelo.to(device)
D_p = D_p.to(device)
X_train = X_train.to(device)
Y_train = Y_train.to(device)

print("Iniciando entrenamiento de BuckiNet para Trayectoria Acoplada...")

for epoch in range(num_epochs):
    modelo.train()
    optimizador.zero_grad()

    # Forward: Predicción y obtención de Phi_p (los exponentes de Buckingham)
    predicciones, Phi_p = modelo(X_train)

    # Cálculo de las pérdidas usando tu función buckinet_loss
    # Nota: buckinet_loss ya suma mse_loss + lambda * null_space_penalty
    total_loss = buckinet_loss(predicciones, Y_train, Phi_p, D_p, lambda_null=lambda_fisica)

    # Para monitoreo: calculamos los componentes por separado
    with torch.no_grad():
        mse_comp = nn.MSELoss()(predicciones, Y_train)
        # La penalización es ||D_p @ Phi_p||^2
        fisica_comp = torch.sum(torch.square(torch.matmul(D_p, Phi_p)))

    # Backward y optimización
    total_loss.backward()
    optimizador.step()

    # Guardar progreso
    historial_total.append(total_loss.item())
    historial_mse.append(mse_comp.item())
    historial_fisica.append(fisica_comp.item())

    # Imprimir progreso cada 200 épocas
    if epoch % 200 == 0:
        print(f"Época [{epoch}/{num_epochs}] | "
              f"MSE (Datos): {mse_comp.item():.6f} | "
              f"Física (Nulo): {fisica_comp.item():.6f} |"
              f"Pérdida total: {total_loss.item():.6f}")

print("\nEntrenamiento completado.")
# Out:
# Iniciando entrenamiento de BuckiNet para Trayectoria Acoplada...
# Época [0/5000] | MSE (Datos): 85.893707 | Física (Nulo): 10.536080 |Pérdida total: 191.266769
# Época [200/5000] | MSE (Datos): 19.541786 | Física (Nulo): 6.266317 |Pérdida total: 82.215340
# Época [400/5000] | MSE (Datos): 9.883627 | Física (Nulo): 3.749524 |Pérdida total: 47.387699
# Época [600/5000] | MSE (Datos): 3.119184 | Física (Nulo): 2.232659 |Pérdida total: 25.454155
# Época [800/5000] | MSE (Datos): 1.329630 | Física (Nulo): 1.265416 |Pérdida total: 13.992065
# Época [1000/5000] | MSE (Datos): 0.767406 | Física (Nulo): 0.677190 |Pérdida total: 7.547477
# Época [1200/5000] | MSE (Datos): 0.489670 | Física (Nulo): 0.336405 |Pérdida total: 3.861828
# Época [1400/5000] | MSE (Datos): 0.346569 | Física (Nulo): 0.153088 |Pérdida total: 1.885500
# Época [1600/5000] | MSE (Datos): 0.275660 | Física (Nulo): 0.063637 |Pérdida total: 0.920029
# Época [1800/5000] | MSE (Datos): 0.230462 | Física (Nulo): 0.024633 |Pérdida total: 0.484751
# Época [2000/5000] | MSE (Datos): 0.204065 | Física (Nulo): 0.009608 |Pérdida total: 0.308084
# Época [2200/5000] | MSE (Datos): 0.188809 | Física (Nulo): 0.004566 |Pérdida total: 0.242386
# Época [2400/5000] | MSE (Datos): 0.176306 | Física (Nulo): 0.003129 |Pérdida total: 0.215492
# Época [2600/5000] | MSE (Datos): 0.167534 | Física (Nulo): 0.002810 |Pérdida total: 0.203515
# Época [2800/5000] | MSE (Datos): 0.160882 | Física (Nulo): 0.002776 |Pérdida total: 0.196522
# Época [3000/5000] | MSE (Datos): 0.155584 | Física (Nulo): 0.002806 |Pérdida total: 0.191508
# Época [3200/5000] | MSE (Datos): 0.151174 | Física (Nulo): 0.002847 |Pérdida total: 0.187507
# Época [3400/5000] | MSE (Datos): 0.148433 | Física (Nulo): 0.002898 |Pérdida total: 0.185260
# Época [3600/5000] | MSE (Datos): 0.148969 | Física (Nulo): 0.002962 |Pérdida total: 0.186425
# Época [3800/5000] | MSE (Datos): 0.159775 | Física (Nulo): 0.003024 |Pérdida total: 0.197836
# Época [4000/5000] | MSE (Datos): 0.140243 | Física (Nulo): 0.003056 |Pérdida total: 0.178614
# Época [4200/5000] | MSE (Datos): 0.135789 | Física (Nulo): 0.003096 |Pérdida total: 0.174550
# Época [4400/5000] | MSE (Datos): 0.133624 | Física (Nulo): 0.003146 |Pérdida total: 0.172872
# Época [4600/5000] | MSE (Datos): 0.131545 | Física (Nulo): 0.003187 |Pérdida total: 0.171179
# Época [4800/5000] | MSE (Datos): 0.129575 | Física (Nulo): 0.003229 |Pérdida total: 0.169617
#
# Entrenamiento completado.

# %% [markdown]
# ## Paso 4. Grafico la función de pérdida

# %%
#============================================
# Visualización de resultados
# ============================================

# Evaluamos el modelo en todo el conjunto
with torch.no_grad():
    predicciones, Phi_final = modelo(X_train)

    # Desnormalizamos las predicciones
    #predicciones = predicciones_norm * Y_std + Y_mean

# Gráfica de pérdida
plt.figure(figsize=(8, 5))
plt.plot(historial_total)
plt.yscale('log')
plt.xlabel('Época')
plt.ylabel('Pérdida Total')
plt.title('Curva de Pérdida (escala logarítmica)')
plt.grid(True)

# %% [markdown]
# ## Paso 5. Interpretación de los exponentes

# %%
phi_final = modelo.pi_layer.Phi_p.detach().numpy()

import pandas as pd
# Creamos un DataFrame para que sea legible
# Filas: Nuestras variables de entrada
# Columnas: Los 3 grupos Pi que la red intentó formar
variables = ['l_f', 'l_r', 'delta', 'V', 't']
df_pi = pd.DataFrame(phi_final, index=variables, columns=['Pi_1', 'Pi_2', 'Pi_3'])

print("Matriz de Exponentes Aprendida (Phi_p):")
print(df_pi.round(4))

# Exponentes aprendidos
Phi_final = Phi_p.detach().numpy()
nombres = ['l_f', 'l_r', 'δ', 'V', 't']

print("\n" + "="*60)
print("EXPONENTES APRENDIDOS")
print("="*60)

for i in range(3):
    print(f"\nΠ_{i+1}:", end="")
    for j, var in enumerate(nombres):
        print(f" {var}^{Phi_final[j, i]:+.3f}", end="")
# Out:
# Matriz de Exponentes Aprendida (Phi_p):
#          Pi_1    Pi_2    Pi_3
# l_f   -0.2757  0.7462  0.3135
# l_r   -0.4666 -0.2264 -0.2675
# delta  1.1107 -0.8736 -0.4122
# V      0.7257 -0.5515 -0.0014
# t      0.7231 -0.5533 -0.0000
#
# ============================================================
# EXPONENTES APRENDIDOS
# ============================================================
#
# Π_1: l_f^-0.276 l_r^-0.467 δ^+1.111 V^+0.726 t^+0.723
# Π_2: l_f^+0.746 l_r^-0.226 δ^-0.874 V^-0.552 t^-0.553
# Π_3: l_f^+0.313 l_r^-0.267 δ^-0.412 V^-0.001 t^-0.000

# %% [markdown]
# ## Grafica de la trayectoria

# %%
import matplotlib.pyplot as plt
import numpy as np

def graficar_comparativa(X_real, Y_real, X_pred, Y_pred, mse_final):
    """
    Genera el gráfico de validación para el informe.
    X_real, Y_real: Coordenadas obtenidas de la integración de la ODE.
    X_pred, Y_pred: Coordenadas predichas por la BuckiNet.
    mse_final: El valor del error obtenido (ej. 0.106).
    """

    plt.figure(figsize=(10, 6), dpi=100)

    # 1. Graficar la trayectoria real (Ground Truth)
    plt.plot(X_real, Y_real, color='red', linestyle='-', linewidth=2.5,
             label='Solución ODE (Física Real)')

    # 2. Graficar la predicción de la BuckiNet
    # Usamos línea discontinua azul para observar el solapamiento
    plt.plot(X_pred, Y_pred, color='blue', linestyle='--', linewidth=2,
             label='Predicción BuckiNet')

    # Configuración de ejes y etiquetas
    plt.title('Validación de Trayectoria: Modelo Cinemático vs. Aprendizaje Profundo',
              fontsize=14, fontweight='bold')
    plt.xlabel('Posición Global X [m]', fontsize=12)
    plt.ylabel('Posición Global Y [m]', fontsize=12)

    # Añadir cuadro de texto con el Error Cuadrático Medio
    plt.text(0.05, 0.90, f'MSE: {mse_final:.4f}', transform=plt.gca().transAxes,
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

    # Mejorar la visualización
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.legend(loc='lower right', shadow=True)
    plt.axis('equal') # Mantiene la proporción para que la curva no se vea deformada

    plt.tight_layout()
    plt.show()

# --- Ejemplo de uso con datos simulados ---
# Sustituye estas variables con los arrays de tu modelo
t_sim = np.linspace(0, 10, 100)
x_true = 2 * t_sim**2  # Ejemplo de trayectoria
y_true = 5 * np.sin(t_sim/2)
x_model = x_true + np.random.normal(0, 0.1, 100) # Simulación de la red
y_model = y_true + np.random.normal(0, 0.1, 100)

graficar_comparativa(x_true, y_true, x_model, y_model, 0.1062)

# %%
import torch.nn.functional as F


# Extraemos las predicciones
X_pred = predicciones[:, 0].numpy()
Y_pred = predicciones[:, 1].numpy()
psi_pred = predicciones[:, 2].numpy()


plt.figure(figsize=(10, 3))
# Comparación X
plt.subplot(1, 3, 1)
plt.scatter(X, X_pred, s=1, alpha=0.3)
plt.plot([X.min(), X.max()], [X.min(), X.max()], 'r--', linewidth=2, label='Ideal')
plt.xlabel('X Real [m]')
plt.ylabel('X Predicho [m]')
plt.title(f'Predicción de X (R² = {np.corrcoef(X, X_pred)[0,1]**2:.4f})')
plt.legend()
plt.grid(True)

# Comparación Y
plt.subplot(1, 3, 2)
plt.scatter(Y, Y_pred, s=1, alpha=0.3)
plt.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'r--', linewidth=2, label='Ideal')
plt.xlabel('Y Real [m]')
plt.ylabel('Y Predicho [m]')
plt.title(f'Predicción de Y (R² = {np.corrcoef(Y, Y_pred)[0,1]**2:.4f})')
plt.legend()
plt.grid(True)

# Comparación ψ
plt.subplot(1, 3, 3)
plt.scatter(psi, psi_pred, s=1, alpha=0.3)
plt.plot([psi.min(), psi.max()], [psi.min(), psi.max()], 'r--', linewidth=2, label='Ideal')
plt.xlabel('ψ Real [rad]')
plt.ylabel('ψ Predicho [rad]')
plt.title(f'Predicción de ψ (R² = {np.corrcoef(psi, psi_pred)[0,1]**2:.4f})')
plt.legend()
plt.grid(True)
